# %% [markdown]
# # [オンライン開催]セキュリティから学ぶ機械学習第1回
# *  [How Machine Learning helps Cyber Security ?](https://www.kaggle.com/code/rockystats/how-machine-learning-helps-cyber-security)
# *  [Top 5 Applications of Machine Learning in Cyber Security](https://www.geeksforgeeks.org/top-5-applications-of-machine-learning-in-cyber-security/)
# *  [Cybersecurity Machine Learning Use Cases: Examples](https://vitalflux.com/cybersecurity-machine-learning-use-cases-examples/)
# *  [The Impact of AI and Machine Learning in Cyber-security](https://blog.devgenius.io/the-impact-of-ai-and-machine-learning-in-cyber-security-44e22a373d0e)
#
# *  [セキュリティ分野におけるAI活用の現状と期待(産業総合研究所 第30回AIセミナー（産総研人工知能研究センター，小澤誠一氏）)](https://www.airc.aist.go.jp/seminar_detail/docs/09bd252401da9f9b6d92fb09812932c9226746c3.pdf)

# %% [markdown]
# ## Section0. セキュリティと機械学習の関連性について[導入]
# 人工知能 (AI) と機械学習 (ML) は世界を変革し、私たちの生活と働き方を変えています。これらのテクノロジーは、サイバーセキュリティの分野にも大きな影響を与えています。 ArtificiaI Intelligence（人工知能） と Machine Learning（機械学習） は、サイバー脅威からユーザーを守り、サイバーセキュリティプロセスを改善し、リアルタイムでサイバー攻撃を検出して防御するための革新的なソリューションを提供しています。この勉強会では全6回を通して、サイバーセキュリティにおけるML の影響と、これらのテクノロジーがセキュリティ分野にどのような変化を与えているかについて、基本的な内容にとどめつつも学んでいきます。
#
# **セキュリティタスクに寄与する機械学習の例**
# (引用元: The Impact of AI and Machine Learning in Cyber-security)
#
# *  **自動化された脅威の検出と対応**:
# AI および ML アルゴリズムは、大量のデータを迅速に分析し、潜在的なサイバー脅威を特定できます。これにより、組織はサイバー攻撃をリアルタイムで検出して対応できるようになり、侵害の検出と対応にかかる時間を短縮できます。 AI と ML を使用すると、組織は脅威を特定して優先順位を付けるプロセスを自動化し、セキュリティチームをより戦略的なタスクに集中させることができます。
#
# *  **侵入検知の改善**:
# 侵入検知システム (IDS) は、組織のネットワークへの不正アクセスを検出して警告するように設計されています。 AI および ML アルゴリズムは、ネットワーク トラフィックをリアルタイムで分析し、潜在的な侵入を示す異常を特定できます。これにより、組織は侵入をより早期に検出し、より迅速に対応できるようになり、侵害の影響を軽減できます。
#
# *  **セキュリティ分析の強化**:
# セキュリティ分析は、潜在的なセキュリティ脅威を特定するためにデータを収集および分析するプロセスです。 AI および ML アルゴリズムは、組織がセキュリティデータをより効果的に収集および分析するのに役立ち、潜在的な脅威を特定して迅速に対応することを容易にします。 AI と ML を使用すると、組織はセキュリティ分析のプロセスを自動化し、セキュリティチームを解放して他のタスクに集中させることもできます。
#
# *  **脆弱性管理の改善**:
# 脆弱性管理は、組織のシステムとネットワークにおけるセキュリティの弱点を特定して軽減するプロセスです。 AI および ML アルゴリズムは、組織が脆弱性をより迅速かつ正確に特定し、侵害のリスクを軽減するのに役立ちます。 AI と ML を使用すると、組織は脆弱性管理のプロセスを自動化し、セキュリティ チームを解放して他のタスクに集中させることもできます。
#
# *  **ネットワークセキュリティの強化**:   ネットワークセキュリティは、組織の機密データとシステムを保護するために重要です。 AI および ML アルゴリズムは、組織がネットワークベースの脅威をリアルタイムで特定して対応するのに役立ちます。これにより、組織は脅威をより迅速に検出して対応し、侵害の影響を軽減できます。
#
# *  **エンドポイント セキュリティの向上**:
# エンドポイントセキュリティは、ラップトップやスマートフォンなどの組織のデバイスをサイバー脅威から保護するプロセスです。 AI および ML アルゴリズムは、組織がエンドポイントベースの脅威をリアルタイムで検出して対応するのに役立ちます。これにより、組織は脅威をより迅速に検出して対応し、侵害の影響を軽減できます。
#
# *  **フィッシング保護の改善**(今日やる内容):
# フィッシング攻撃は、ソーシャルエンジニアリングの戦術を使用して被害者をだまして機密情報を提供させる、一般的なタイプのサイバー脅威です。 AI および ML アルゴリズムは、組織がフィッシング攻撃をより迅速かつ正確に検出して対応し、侵害のリスクを軽減するのに役立ちます。
#
# *  **誤検知アラートの削減**:
# 誤検知アラートは、システムが潜在的な脅威を識別したときに生成されるセキュリティアラートですが、その脅威は実際には無害です。 AI および ML アルゴリズムは、組織が誤検知アラートを減らし、実際の脅威を特定して対応することを容易にするのに役立ちます。
#
# *  **インシデント対応の改善**:
# インシデント対応は、セキュリティ違反またはインシデントに対応するプロセスです。 AI および ML アルゴリズムは、組織がより迅速かつ効果的にインシデントに対応し、侵害の影響を軽減するのに役立ちます。 AI と ML を使用すると、組織はインシデント対応のプロセスを自動化し、セキュリティ チームを解放して他のタスクに集中させることもできます。
#
# サイバーセキュリティにおける AI と ML の影響は非常に大きいものです。これらのテクノロジーは、サイバー脅威から防御し、サイバーセキュリティプロセスを改善し、リアルタイムでサイバー攻撃を検出して対応するための新しい革新的なソリューションを提供しています。サイバーセキュリティで AI と ML を使用することで、組織は脅威をより迅速かつ効果的に検出して対応できるようになり、侵害・損害による影響を軽減できます。さらに、AI および ML アルゴリズムは、サイバーセキュリティの多くのタスクを自動化し、セキュリティチームをより戦略的なタスクに集中させることができます。
#
# ただし、サイバーセキュリティで AI と ML を使用すると、いくつかの重要な懸念も生じます。主な懸念事項の 1 つは、AI および ML システムがサイバー犯罪者によってハッキングまたは操作される可能性です。これにより、AI および ML システム自体が組織を攻撃するための武器として使用される可能性があります。さらに、特に脅威の検出と対応に関しては、サイバーセキュリティにおける AI および ML アルゴリズムの精度と信頼性に関する懸念もあります。
#
# これらのリスクを軽減するために、組織はサイバーセキュリティで AI と ML を実装および使用する方法に注意する必要があります。また、これらのテクノロジーに関連するリスクを管理するために、適切なガバナンス、セキュリティ、および監視が整っていることを確認する必要があります。さらに、組織は、機密データとシステムを保護および保護するように設計された倫理的な AI および ML アルゴリズムの開発に投資する必要があります。
#
# 結論として、サイバーセキュリティにおける AI と ML の影響は大きく、これらのテクノロジーはこの分野を変革する可能性を秘めています。ただし、組織は、サイバーセキュリティで AI と ML を実装および使用する方法に注意して、リスクを軽減しながらこれらのテクノロジのメリットを享受できるようにする必要があります。適切なアプローチと投資により、AI と ML は、デジタル世界の機密データとシステムのセキュリティと保護を大幅に改善する可能性を秘めています。
#
#
# **サイバーセキュリティにおける機械学習の応用**
# (引用元: セキュリティ分野におけるAI活用の現状と期待 p7)
# *   マルウエア解析(静的/動的)
# マルウエア検知・分類
# *   不正侵入検知(IDS/IPS)
# 異常検知, 攻撃分類・検知, ハニーポット観測・分析
# *   広域攻撃観測（ダークネット分析）
# 異常検知,  攻撃分類・検知, ボットネットの活動検知・分析
# *   Webベース攻撃検知
# 悪性サイト・悪性スパムメール検知, 悪性JavaScript検知
# *   サイバー攻撃情報の収集・分析
# 表層Web解析（SNS、セキュリティブログ・レポートなど）, リスト項目深層Web解析（ダークマーケット、ダークフォーラムなど）

# %% [markdown]
# ## Section1. フィッシングサイトの検出
# ![任意の画像名を付ける](https://drive.google.com/uc?id=1UYcF_Q5hmB6EAA9fIiiKPNCIg6pOV0IG)
#
# ソーシャルエンジニアリングは、現代の個人や組織の多くが直面している最も脅威となる分野の１つです。
# よく知られている、一般的なソーシャルエンジニアリングを悪用した手法の１つには、フィッシングがあります。
# 攻撃者は偽装したメールやWebサイトを使い、個人や企業に攻撃を仕掛けます。企業においては膨大な数のメールを受信するために全てのメールについてそれらがフィッシングのメールなのかどうか、検出することはなかなか難しいものとなります。機械的に、自動的にこれらフィッシングなどのメールについて適切なフィルタリング（防御）することは非常に重要となります。
#
# 上記のような例をもとに、まずは機械学習の手法に慣れつつ、フィッシングサイトを検出する機械学習モデルを簡易に作成します。これら作成プロセスに、データセットのロード方法や、データセットの分割方法、ハイパーパラメータのチューニング、訓練、結果の評価と一連の作業を試しにやってみましょう。

# %% [markdown]
# ### Section1-1. ソーシャルエンジニアリング概要
# ```
# ソーシャルエンジニアリングとは、ネットワークに侵入するために必要となるパスワードなどの重要な情報を、
# 情報通信技術を使用せずに盗み出す方法です。その多くは人間の心理的な隙や行動のミスにつけ込むものです。
# ```
# (引用元: [総務省 ソーシャルエンジニアリングの対策](https://www.soumu.go.jp/main_sosiki/joho_tsusin/security/business/staff/12.html#:~:text=%E3%82%BD%E3%83%BC%E3%82%B7%E3%83%A3%E3%83%AB%E3%82%A8%E3%83%B3%E3%82%B8%E3%83%8B%E3%82%A2%E3%83%AA%E3%83%B3%E3%82%B0%E3%81%A8%E3%81%AF%E3%80%81%E3%83%8D%E3%83%83%E3%83%88%E3%83%AF%E3%83%BC%E3%82%AF,%E3%83%9F%E3%82%B9%E3%81%AB%E3%81%A4%E3%81%91%E8%BE%BC%E3%82%80%E3%82%82%E3%81%AE%E3%81%A7%E3%81%99%E3%80%82))
#
# 攻撃者は、ソーシャルエンジニアリングを使用して他者を騙すことで機密情報を手に入れるということ。
#
#
# *   **誘惑**
# 対象者に報酬やギフトを約束して、情報を開示させたりする行為全般
# *   **なりすまし**
# 関係者や本人そのものとして振る舞う行為全般
# *   **ゴミ漁り**
# （比喩表現として）ゴミ箱から（住所やメールアドレス、氏名その他個人情報）有用な情報を収集する行為全般
# *   **ショルダーハック**
# 攻撃対象者の見えないところから、例えばPCの画面を覗き見ること、そこから有益な情報を収集する行為全般
# *   **フィッシング**
# 最もよく使われる手法の１つ。実在する組織や企業、サービスなどを装って攻撃者が攻撃対象者のメールアドレスや電話番号にSMSやメールなどを送付して偽サイトへ誘導しアクセスさせてIDやパスワード、電話番号、クレジットカード番号などを入力させる。また攻撃対象者を騙す偽サイトのことを、フィッシングサイトという。

# %% [markdown]
# ### Section1-2. ロジスティック回帰を使用したフィッシングサイトの検出
# ロジスティック回帰アルゴリズム
#
#
# *   [【Python】ロジスティック回帰による2値分類｜scikit-learnを用いた機械学習モデル開発実践](https://di-acc2.com/analytics/ai/16440/)
# *   [2. Pythonで綴る多変量解析　5-1. ロジスティック回帰分析(scikit-learn)](https://qiita.com/y_itoh/items/6a67fc4a1a6930f0a4b5)
# *  [Pythonで前処理から始めるロジスティック回帰](https://www.jstage.jst.go.jp/article/tenrikiyo/19/2/19_19-008/_pdf#:~:text=3%EF%BC%89%20%E5%A4%9A%E9%87%8D%E5%85%B1%E7%B7%9A%E6%80%A7%20%E3%83%AD%E3%82%B8%E3%82%B9%E3%83%86%E3%82%A3%E3%83%83%E3%82%AF,%E7%B7%9A%E6%80%A7%E3%81%8C%E3%81%82%E3%82%8B%E3%81%A8%E8%A8%80%E3%81%86%EF%BC%8E)
#
# 簡単にいうと、２値分類（２種類のグループに分けること）を行うために利用される、よく知られた手法の１つ。
#
# ここでは、[URI Machine Learning Repのフィッシングサイトのデータセット](https://archive.ics.uci.edu/ml/datasets/Phishing+Websites)を利用します。
#
# ![任意の画像名を付ける](https://drive.google.com/uc?id=1d9ie4pHRVRykIl-IlIoQoFJsl2OhkeYH)

# %%
# dataset.csvを直接このGoogle Driveへドロップしてください

# %%
# !ls
# Out:
# dataset.csv  sample_data

# %% [markdown]
# **optuna**について後ほど説明しますが、とりあえずインストールする

# %%
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# 必要なパッケージやライブラリをインポートします

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split
import numpy as np
import optuna
from sklearn.model_selection import cross_validate

training_data = np.genfromtxt('dataset.csv', delimiter=',', dtype=np.int32)

# %% [markdown]
# ここでは変数、Xに説明変数(最終列以外の列全て)を、Yに目的変数(最終列のみ)を格納する。
# データセットには、８０％を訓練用データ、20%をテスト用データとして分割します。このやり方をホールドアウト検証と言います。

# %%
X = training_data[:,:-1]
y = training_data[:, -1]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=True, random_state=101)

# %% [markdown]
# scikit-learnのロジスティック回帰を使った検出器を作成します。

# %%
classifier = LogisticRegression(solver='lbfgs')

# 訓練用データを使って検出器を訓練する。
classifier.fit(X_train, y_train)
# 予測させる。
predictions = classifier.predict(X_test)

# %% [markdown]
# `accuracy_score `を使用して、このフィッシング検出モデルの正解率を確認してみます。

# %%
# このフィッシング検出器の正解率を出力させる。
accuracy = 100.0 * accuracy_score(y_test, predictions)
print("The accuracy of your Logistic Regression on testing data is: {}".format(accuracy))
# Out:
# The accuracy of your Logistic Regression on testing data is: 92.22071460877432

# %% [markdown]
# この９２％というものは、フィッシングサイトとそうでないものを９２％の割合で正しく見抜けるモデルといえます

# %% [markdown]
# **ホールドアウト検証**と**交差検証法**
# `cross_val_score`を利用してK分割交差検証を実施してみましょう。

# %%
from sklearn.model_selection import cross_val_score

# 交差検証(5分割)による汎化性能の評価
scores = cross_val_score(classifier, X_train, y_train, cv=5)
# 評価結果の出力
print("Evaluated score by cross-validation(k=5): {}".format(100 * scores.mean()))
# Out:
# Evaluated score by cross-validation(k=5): 92.88792144243878

# %% [markdown]
# 上記の交差検証でも、おおよそ92%の正解率

# %% [markdown]
# ### Section1-3. ハイパーパラメータのチューニング
# 次に、ハイパーパラメータのチューニングを実施してみましょう。
# ここで登場するハイパーパラメータとは、機械学習アルゴリズムの挙動を制御するためのパラメータのことを指します。
# このパラメータを調整することによって、機械学習アルゴリズムが力を発揮する空間や次元を見つけ出してその課題やタスクごとに適した機械学習モデルを作成することが可能となります。

# %% [markdown]
# #### Section1-3-1. チューニング方法
# チューニングを手動でやろうとすると、どうしても経験や勘といった属人化したタスクになってしまう。そこで、チューニングツールを利用することが望ましい。チューニングツールの１例としては、scikit-learnの`GridSearchCV`が用意されている。この方法は、ただし総当たりの手法をとるために時間とリソースがかかってしまうという課題がある。このチューニングの根本的な課題を解決するツールに、Preferred Networksの [optuna](https://optuna.readthedocs.io/en/stable/)がある。
#
# optuna は、 [Tree-structured Parzen Estimator](https://proceedings.neurips.cc/paper_files/paper/2011/file/86e8f7ab32cfd12577bc2619bc635690-Paper.pdf) というベイズ最適化アルゴリズムの１種を活用して、有望な値を履歴に基づいて効率的に見つけ出す、を繰り返して最適なパラメータを見つけてくれるものです。

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split
import numpy as np
import optuna
from sklearn.model_selection import cross_validate

class Objective:
    def __init__(self, X, y):
        # 変数X,yの初期化
        self.X = X
        self.y = y

    def __call__(self, trial):
        # ターゲットのハイパーパラメータの設定
        params = {
            # 最適化に使用するアルゴリズムの候補をカテゴリとして指定
            'solver' : trial.suggest_categorical('solver',\
                    ['newton-cg', 'lbfgs', \
                    'liblinear', 'sag', 'saga']),
            # 正則化の強さに0.0001から10までを指定
            'C': trial.suggest_loguniform('C', 0.0001, 10),
            # ソルバーが収束するまでの最大反復回数
            'max_iter': trial.suggest_int('max_iter', 100, 100000)
            }

        model = LogisticRegression(**params)

        # 評価指標として正解率の最大化を目指す
        scores = cross_validate(model,
                                X=self.X, y=self.y,
                                scoring='accuracy',
                                n_jobs=-1)
        return scores['test_score'].mean()

# ハイパーパラメータの探索
objective = Objective(X_train, y_train)
study = optuna.create_study(direction='maximize')
study.optimize(objective, timeout=60)
# ベストのパラメータの出力
print('params:', study.best_params)
# Out:
# [I 2023-04-15 01:25:25,416] A new study created in memory with name: no-name-5ee7ac26-6c91-4f3b-bc4e-2a7b5b064f83
# <ipython-input-6-cccc9e3f9b43>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C': trial.suggest_loguniform('C', 0.0001, 10),
# [I 2023-04-15 01:25:27,923] Trial 0 finished with value: 0.9292185169932651 and parameters: {'solver': 'newton-cg', 'C': 0.5449762844761709, 'max_iter': 79023}. Best is trial 0 with value: 0.9292185169932651.
# <ipython-input-6-cccc9e3f9b43>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'C': trial.suggest_loguniform('C', 0.0001, 10),
# ...

# %% [markdown]
# ハイパーパラメータチューニングの結果は下記のようになる。
# `confusion_matrix` を使って混合行列を出しつつ正解率を確認してみる。

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

model = LogisticRegression(
    # ハイパーパラメータ探索で特定した値を設定
    solver = study.best_params['solver'],
    C = study.best_params['C'],
    max_iter = study.best_params['max_iter']
)

model.fit(X_train, y_train)
pred = model.predict(X_test)
# 正解率の出力
print("Accuracy: {:.5f} %".format(100 * accuracy_score(y_test, pred)))
# 混同行列の出力
print(confusion_matrix(y_test, pred))
# Out:
# Accuracy: 92.35640 %
# [[ 874   97]
#  [  72 1168]]

# %% [markdown]
# Accuracy, Precision, F-Scoreについて、
# [分類問題の予測結果の評価指標（Accuracy, Precision, Recall, F値, AUC）について整理してみた](https://tech.ledge.co.jp/entry/metrics) を参考に説明します。

# %%
from sklearn.metrics import precision_score, recall_score

# 適合率の確認
print("Precision: {:.5f} %".format(100 * precision_score(y_test, pred)))
# 再現率の確認
print("Recall: {:.5f} %".format(100 * recall_score(y_test, pred)))
# Out:
# Precision: 92.33202 %
# Recall: 94.19355 %

# %% [markdown]
# ### Section1-4. 決定木を使用したフィッシング検出器
# ロジスティック回帰だけでなく、決定ぎを利用したフィッシングの検出器を作成してみる。
# [Scikit-learnのDecisionTreeClassifierクラスによる分類木](https://helve-blog.com/posts/python/sklearn-classification-tree/)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score 
import numpy as np
import optuna
from sklearn.model_selection import cross_validate

class Objective_DTC:
    def __init__(self, X, y):
        # 変数X,yの初期化
        self.X = X
        self.y = y

    def __call__(self, trial):
        # ターゲットのハイパーパラメータの設定
        params = {
            'criterion':\
            trial.suggest_categorical('criterion', ['gini', 'entropy']),
            'splitter':\
            trial.suggest_categorical('splitter', ['best', 'random']),
            'max_features':\
            trial.suggest_categorical('max_features', ['auto', 'sqrt', 'log2']),
            'min_samples_split':\
            trial.suggest_int('min_samples_split', 2, 64),
            'max_depth':\
            trial.suggest_int('max_depth', 2, 64)
            }

        model = DecisionTreeClassifier(**params)

        # 評価指標として正解率の最大化を目指す
        scores = cross_validate(model,
                                X=self.X, y=self.y,
                                scoring='accuracy',
                                n_jobs=-1)
        return scores['test_score'].mean()

objective = Objective_DTC(X_train, y_train)
study = optuna.create_study(direction='maximize')
# timeoutに60を指定し、最大で1分間探索させる
study.optimize(objective, timeout=60)
print('params:', study.best_params)
# Out:
# [I 2023-04-15 01:26:25,794] A new study created in memory with name: no-name-f5f9acc7-3805-4156-a057-a0a80f123d4d
# [I 2023-04-15 01:26:25,955] Trial 0 finished with value: 0.9153093498128912 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_features': 'auto', 'min_samples_split': 46, 'max_depth': 33}. Best is trial 0 with value: 0.9153093498128912.
# [I 2023-04-15 01:26:26,090] Trial 1 finished with value: 0.9284274931001232 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_features': 'sqrt', 'min_samples_split': 11, 'max_depth': 13}. Best is trial 1 with value: 0.9284274931001232.
# [I 2023-04-15 01:26:26,226] Trial 2 finished with value: 0.9261665204412852 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_features': 'sqrt', 'min_samples_split': 20, 'max_depth': 50}. Best is trial 1 with value: 0.9284274931001232.
# ...

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score

model = DecisionTreeClassifier(
    # ハイパーパラメータ探索で特定した値を設定
    criterion = study.best_params['criterion'],
    splitter = study.best_params['splitter'],
    max_features = study.best_params['max_features'],
    min_samples_split = study.best_params['min_samples_split'],
    max_depth = study.best_params['max_depth']
)

model.fit(X_train, y_train)
pred = model.predict(X_test)

# 正解率の出力
print("Accuracy: {:.5f} %".format(100 * accuracy_score(y_test, pred)))
# 適合率の出力
print("Precision: {:.5f} %".format(100 * precision_score(y_test, pred,)))
# 再現率の出力
print("Recall: {:.5f} %".format(100 * recall_score(y_test, pred)))
# 混同行列の出力
print(confusion_matrix(y_test, pred))
# Out:
# Accuracy: 94.57259 %
# Precision: 95.75163 %
# Recall: 94.51613 %
# [[ 919   52]
#  [  68 1172]]
# /usr/local/lib/python3.9/dist-packages/sklearn/tree/_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
